# %% [markdown]
# # Random Per-Cell 14 px-Patch Stimulation
#
# Single-cell optogenetic stimulation experiment using `RandomStimPerCell14pxPatches`.
# For every segmented cell each FOV is tiled into a regular grid of 14 px patches; only
# patches that are entirely inside the cell mask are kept, and one is chosen at random
# to receive a 10 px-diameter dot stimulation. The selected patch (and its bounding
# box) is written to `stim_patches/{fname}.parquet` so post-processing can re-extract
# image features for that exact patch and correlate them with the local cell response.
#
# **Workflow overview:**
# 1. Initialise the DMD-equipped microscope and define imaging / stim / optocheck channels.
# 2. Configure the pipeline with Cellpose segmentation, the new per-cell patch stimulator, ERK-KTR feature extraction, and tracking.
# 3. Pick FOV positions in napari and build the acquisition as a single RTMSequence phase: 5 min baseline, single stim pulse, 15 min response, optocheck on the last frame.
# 4. Validate and run the experiment (~24 FOVs in parallel, 30 s intervals, 20 min total).
# 5. Post-process: merge per-FOV tracks into `exp_data.parquet` and merge the patch sidecar files into `stim_patches.parquet`.

# %%
import os
import time
from faro.core.data_structures import (
    Channel,
    PowerChannel,
    RTMSequence,
    SegmentationMethod,
    combine,
)
import faro.core.utils as utils

# %% [markdown]
# ### Experimental Settings
#
# **Microscope:** Moench (DMD-based). Per-cell single-cell patterning needs the DMD.
#
# **What to customise below:**
# - `SLEEP_BEFORE_EXPERIMENT_START_in_H` -- delay before acquisition starts (hours).
# - `base_path` / `experiment_name` -- output directory. All data (zarr, tracks, TIFFs, sidecar parquets) is saved under this path.
# - `INTERVAL_S`, `BASELINE_MIN`, `RESPONSE_MIN` -- experiment timing.
# - `stim_channel` -- the stimulation light channel. Adjust `power` (0-100) and `exposure` (ms).
# - `imaging_channels` -- channels acquired every timepoint. Channel 0 is used for segmentation.
# - `optocheck_channel` -- reference channel acquired on the last frame to verify optogenetic tool expression.

# %%
from faro.microscope.pertzlab.moench import Moench

mic = Moench(None)
mic.mmc.setChannelGroup("TTL_ERK")  # adjust to the channel group used in MicroManager

# %%
## Configuration
SLEEP_BEFORE_EXPERIMENT_START_in_H = 0  # delay before acquisition (hours); 0 = start immediately

INTERVAL_S = 30          # 30 s between frames

# Frame counts per phase (all 0-indexed inside a single phase)
N_BASELINE = 15          # imaging frames before the stim block
N_STIM     = 30          # consecutive stim frames (mask stays fixed across these)
N_RECOVERY = 30          # imaging frames after the stim block
N_FRAMES   = N_BASELINE + N_STIM + N_RECOVERY

# Stim frame indices: a contiguous block right after baseline.
STIM_FRAMES = list(range(N_BASELINE, N_BASELINE + N_STIM))

## Storage -- all output (zarr, tracks, TIFFs, stim_patches sidecar) goes under this directory
base_path = r"Z:\lhinder\data\rtm_mm_data\exp_440"
experiment_name = "random_stim_per_cell_14px_patches"
path = os.path.join(base_path, experiment_name)

## Stimulation channel -- light used for optogenetic activation
stim_channel = PowerChannel(
    config="CyanStim",
    exposure=250,
    group="TTL_ERK",
    power=18,
)

## Imaging channels -- order matters (channel 0 is used for segmentation)
imaging_channels = (
    PowerChannel(config="mScarlet3", exposure=200, group="TTL_ERK", power=5),   # ERK-KTR reporter
    PowerChannel(config="miRFP", exposure=1100, group="TTL_ERK", power=99),       # PIP

)

## Optocheck channel -- acquired only on ref_frames; longer exposure to measure optogenetic tool expression
optocheck_channel = PowerChannel(config="mCitrine", exposure=300, group="TTL_ERK", power=30)

print(f"Experiment timing: {N_FRAMES} frames @ {INTERVAL_S}s = {(N_FRAMES-1)*INTERVAL_S/60:.1f} min")
print(f"Baseline : frames 0..{N_BASELINE-1} ({N_BASELINE*INTERVAL_S/60:.1f} min)")
print(f"Stim     : frames {STIM_FRAMES[0]}..{STIM_FRAMES[-1]} ({N_STIM*INTERVAL_S/60:.1f} min)")
print(f"Recovery : frames {STIM_FRAMES[-1]+1}..{N_FRAMES-1} ({N_RECOVERY*INTERVAL_S/60:.1f} min)")
print(f"Optocheck: last frame ({N_FRAMES-1})")
# Out:
# Experiment timing: 75 frames @ 30s = 37.0 min
# Baseline : frames 0..14 (7.5 min)
# Stim     : frames 15..44 (15.0 min)
# Recovery : frames 45..74 (15.0 min)
# Optocheck: last frame (74)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Pipeline Setup
#
# `RandomStimPerCell14pxPatches` divides each FOV into 14 px patches and stamps a 10 px-diameter
# dot onto one randomly selected patch per cell. Selection is seeded by `(fov, fov_timestep)` so
# re-running post-processing reproduces the exact patches that were illuminated live. Patch
# coordinates are accumulated in-memory while the experiment runs and merged directly into
# `exp_data.parquet` after acquisition (no separate sidecar file).
#
# **Components below:**
# - **Segmentation:** Cellpose v4 on imaging channel 0 (nuclear marker). `save_tracked=True` writes tracked label masks alongside raw segmentation.
# - **Stimulator:** `RandomStimPerCell14pxPatches(seed=0)`.
# - **Feature extraction:** `FE_ErkKtr("labels")` for cytoplasmic/nuclear ERK-KTR ratio.
# - **Tracker:** `TrackerTrackpy(search_range=50)` (max 50 px displacement between frames).
# - **Optocheck:** `OptoCheckFE(used_mask="labels")` measures optogenetic reporter intensity on `ref_frames`.

# %%
from faro.stimulation.random_stim_per_cell_14px_patches import RandomStimPerCell14pxPatches
from faro.tracking.trackpy import TrackerTrackpy
from faro.tracking.motile_tracker import TrackerMotile
from faro.feature_extraction.erk_ktr import FE_ErkKtr
from faro.feature_extraction.optocheck import OptoCheckFE
from faro.segmentation.cellpose_v4 import CellposeV4

segmentators = [
    SegmentationMethod(
        name="labels",
        segmentation_class=CellposeV4(gamma=0.3),
        use_channel=0,
        save_tracked=True,
    )
]

stimulator = RandomStimPerCell14pxPatches(seed=0)
feature_extractor = FE_ErkKtr("labels")
#tracker = TrackerTrackpy(search_range=50)
tracker = TrackerMotile(search_range=70)
optocheck = OptoCheckFE(used_mask="labels")

from faro.core.pipeline import ImageProcessingPipeline

pipeline = ImageProcessingPipeline(
    storage_path=path,
    segmentators=segmentators,
    feature_extractor=feature_extractor,
    tracker=tracker,
    stimulator=stimulator,
    feature_extractor_ref=optocheck,
)

from faro.core.controller import Controller
from faro.core.writers import OmeZarrWriter

writer = OmeZarrWriter(storage_path=path)

# %% [markdown]
# ### GUI
#
# Open the napari viewer with the MicroManager widget. Use the MDA widget to pick the ~24 FOV positions for `generate_fov_positions` below.

# %%
from napari_micromanager import MainWindow
import napari

viewer = napari.Viewer()
mm_wdg = MainWindow(viewer)
mm_wdg._mmc = mic.mmc
viewer.window.add_dock_widget(mm_wdg)
# Out:
# Error creating widget for Camera-PreampOffLimit: argument 2 overflowed: value must be in the range -2147483648 to 2147483647

# %% [markdown]
# ### DMD calibration
#
# The DMD must be calibrated against the camera before running a single-cell stim experiment so that the patch dots land on the right pixels.

# %%
mic.dmd.affine = None
import pymmcore_plus

# Quiet the pymmcore-plus log spam during calibration.
pymmcore_plus.configure_logging(stderr_level="CRITICAL")

# calibrate_dmd now connects only its own frameReady collectors and
# disconnects only them, so napari-micromanager's preview keeps working
# throughout calibration. The old mm_wdg._core_link.cleanup() +
# CoreViewerLink-recreate dance is no longer needed -- and the cleanup()
# was itself what suppressed the preview of the calibration spots.
mic.calibrate_dmd(verbose=True, radius=4)

# %% [markdown]
# # Use this to focus the DMD (will activate your sample!)

# %%
# --- Cell 6a: arm DMD checkerboard for live focus ---
# Disable OverlapMode so the DMD latches the pattern continuously
# instead of waiting for per-frame camera TTL. OverlapMode=On is
# correct during the real MDA (tests pass under it), but napari's
# Live view doesn't reliably produce the TTL pulses the DMD expects,
# so in that context ``displaySLMImage`` behaves as a one-shot flash
# and the DMD sits in an unpredictable idle state between camera
# frames. Flipping to OverlapMode=Off makes the pattern visible
# throughout Live.
_prev_overlap = mic.mmc.getProperty(mic.dmd.name, "OverlapMode")
mic.mmc.setProperty(mic.dmd.name, "OverlapMode", "Off")

#£mic.mmc.setConfig(CHANNEL_GROUP, STIM_CHANNEL)
#mic.mmc.setExposure(STIM_EXPOSURE_MS)
# Long SLM exposure so the pattern stays on as napari Live streams.
mic.mmc.setSLMExposure(mic.dmd.name, 200000)
try:
    mic.mmc.setProperty("LED", "Cyan_Level", 1)
except Exception as e:
    print(f"(skipping LED power set: {e})")
mic.dmd.checker_board(pixels=100)
print(f"DMD checker armed (OverlapMode was {_prev_overlap!r}, now Off).")
print("Press Live in napari-mm and refocus. Run the next cell to disarm.")
# Out:
# DMD checker armed (OverlapMode was 'Off', now Off).
# Press Live in napari-mm and refocus. Run the next cell to disarm.

# %%
# --- Cell 6b: disarm DMD + restore OverlapMode ---
mic.dmd.all_off()
try:
    mic.mmc.setProperty(mic.dmd.name, "OverlapMode", _prev_overlap)
    print(f"DMD blanked, OverlapMode restored to {_prev_overlap!r}.")
except NameError:
    print("DMD blanked. (OverlapMode state unknown — arm cell wasn't run.)")
# Out:
# DMD blanked, OverlapMode restored to 'Off'.

# %% [markdown]
# ### Build acquisition events
#
# Single-phase experiment: 41 frames at 30 s intervals (20 min total). Stim fires once at frame 10
# (after the 5 min baseline) and the optocheck channel is acquired on the last frame.
#
# `apply_fov_batching(events, time_per_fov=2.0)` keeps the timing valid even if 24 FOVs cannot all be
# imaged within one 30 s interval -- FOVs are split into sequential sub-batches automatically.

# %%
fov_positions = utils.generate_fov_positions(mic, viewer=viewer)

phase = RTMSequence(
    time_plan={"interval": INTERVAL_S, "loops": N_FRAMES},
    stage_positions=fov_positions,
    channels=imaging_channels,
    stim_channels=(stim_channel,),
    stim_frames=STIM_FRAMES,
    ref_channels=(optocheck_channel,),
    ref_frames=[-1],
    rtm_metadata={
        "phase_name": "RandomPatchStim",
        "phase_id": 0,
        "treatment_name": "Random per-cell 14px-patch stimulation",
    },
)

# combine() flattens the RTMSequence into per-event records that the controller and
# apply_fov_batching can consume; passing axis="t" is a no-op for a single phase.
events = combine(phase, axis="t")
events = utils.apply_fov_batching(events, time_per_fov=4.0)

print(f"Total events: {len(events)}")
print(f"FOVs: {len(fov_positions)}")
utils.events_to_dataframe(events).sort_values("timestep")
# Out:
# Total events: 2550
# FOVs: 34
#       fov  timestep     time    x_pos   y_pos z_pos  \
# 0       0         0      0.0 -10732.0 -7458.5  None
# 1       1         0      0.0 -10464.7 -8424.8  None
# 2       2         0      0.0 -10331.6 -9088.0  None
# 3       3         0      0.0  -9819.2 -9307.0  None
# 4       4         0      0.0  -9154.8 -9270.1  None
# ...   ...       ...      ...      ...     ...   ...
# 2545   29        74  11212.0 -13487.4 -8916.0  None
# 2546   30        74  11212.0 -14160.9 -8802.4  None
# 2547   31        74  11212.0 -14718.4 -8111.6  None
# 2548   32        74  11212.0 -14881.0 -7207.0  None
# 2549   33        74  11212.0 -10731.9 -7061.5  None
#
#                                                channels stim_channels  \
# 0     ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 1     ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 2     ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 3     ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 4     ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# ...                                                 ...           ...
# 2545  ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 2546  ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 2547  ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 2548  ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
# 2549  ({'config': 'mScarlet3', 'exposure': 200.0, 'g...            ()
#
#                                            ref_channels   stim    ref  \
# 0                                                    ()  False  False
# 1                                                    ()  False  False
# 2                                                    ()  False  False
# 3                                                    ()  False  False
# 4                                                    ()  False  False
# ...                                                 ...    ...    ...
# 2545  ({'config': 'mCitrine', 'exposure': 300, 'grou...  False   True
# 2546  ({'config': 'mCitrine', 'exposure': 300, 'grou...  False   True
# 2547  ({'config': 'mCitrine', 'exposure': 300, 'grou...  False   True
# 2548  ({'config': 'mCitrine', 'exposure': 300, 'grou...  False   True
# 2549  ({'config': 'mCitrine', 'exposure': 300, 'grou...  False   True
#
#            phase_name  phase_id                          treatment_name  \
# 0     RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 1     RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 2     RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 3     RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 4     RandomPatchStim         0  Random per-cell 14px-patch stimulation
# ...               ...       ...                                     ...
# 2545  RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 2546  RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 2547  RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 2548  RandomPatchStim         0  Random per-cell 14px-patch stimulation
# 2549  RandomPatchStim         0  Random per-cell 14px-patch stimulation
#
#       stim_power  stim_exposure
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
# ...          ...            ...
# 2545         NaN            NaN
# 2546         NaN            NaN
# 2547         NaN            NaN
# 2548         NaN            NaN
# 2549         NaN            NaN
#
# [2550 rows x 16 columns]

# %%
events
# Out:
# [RTMEvent(index={'t': 0, 'p': 0}, min_start_time=0.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 1}, min_start_time=0.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 2}, min_start_time=0.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 3}, min_start_time=0.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 4}, min_start_time=0.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 5}, min_start_time=0.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 0, 'p': 6}, min_start_time=0.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 0}, min_start_time=30.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 1}, min_start_time=30.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 2}, min_start_time=30.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 3}, min_start_time=30.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 4}, min_start_time=30.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 5}, min_start_time=30.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 1, 'p': 6}, min_start_time=30.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 0}, min_start_time=60.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 1}, min_start_time=60.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 2}, min_start_time=60.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 3}, min_start_time=60.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 4}, min_start_time=60.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 5}, min_start_time=60.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 2, 'p': 6}, min_start_time=60.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 0}, min_start_time=90.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 1}, min_start_time=90.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 2}, min_start_time=90.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 3}, min_start_time=90.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 4}, min_start_time=90.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 5}, min_start_time=90.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 3, 'p': 6}, min_start_time=90.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 0}, min_start_time=120.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 1}, min_start_time=120.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 2}, min_start_time=120.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 3}, min_start_time=120.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 4}, min_start_time=120.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 5}, min_start_time=120.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 4, 'p': 6}, min_start_time=120.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 0}, min_start_time=150.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 1}, min_start_time=150.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 2}, min_start_time=150.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 3}, min_start_time=150.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 4}, min_start_time=150.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 5}, min_start_time=150.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 5, 'p': 6}, min_start_time=150.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 0}, min_start_time=180.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 1}, min_start_time=180.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 2}, min_start_time=180.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 3}, min_start_time=180.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 4}, min_start_time=180.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 5}, min_start_time=180.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 6, 'p': 6}, min_start_time=180.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 0}, min_start_time=210.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 1}, min_start_time=210.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 2}, min_start_time=210.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 3}, min_start_time=210.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 4}, min_start_time=210.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 5}, min_start_time=210.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 7, 'p': 6}, min_start_time=210.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 0}, min_start_time=240.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 1}, min_start_time=240.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 2}, min_start_time=240.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 3}, min_start_time=240.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 4}, min_start_time=240.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 5}, min_start_time=240.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 8, 'p': 6}, min_start_time=240.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 0}, min_start_time=270.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 1}, min_start_time=270.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 2}, min_start_time=270.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 3}, min_start_time=270.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 4}, min_start_time=270.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 5}, min_start_time=270.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 9, 'p': 6}, min_start_time=270.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 0}, min_start_time=300.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 1}, min_start_time=300.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 2}, min_start_time=300.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 3}, min_start_time=300.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 4}, min_start_time=300.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 5}, min_start_time=300.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 10, 'p': 6}, min_start_time=300.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 0}, min_start_time=330.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 1}, min_start_time=330.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 2}, min_start_time=330.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 3}, min_start_time=330.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 4}, min_start_time=330.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 5}, min_start_time=330.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 11, 'p': 6}, min_start_time=330.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 0}, min_start_time=360.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 1}, min_start_time=360.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 2}, min_start_time=360.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 3}, min_start_time=360.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 4}, min_start_time=360.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 5}, min_start_time=360.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 12, 'p': 6}, min_start_time=360.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 0}, min_start_time=390.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 1}, min_start_time=390.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 2}, min_start_time=390.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 3}, min_start_time=390.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 4}, min_start_time=390.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 5}, min_start_time=390.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 13, 'p': 6}, min_start_time=390.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 0}, min_start_time=420.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 1}, min_start_time=420.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 2}, min_start_time=420.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 3}, min_start_time=420.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 4}, min_start_time=420.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 5}, min_start_time=420.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 14, 'p': 6}, min_start_time=420.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 15, 'p': 0}, min_start_time=450.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 1}, min_start_time=450.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 2}, min_start_time=450.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 3}, min_start_time=450.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 4}, min_start_time=450.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 5}, min_start_time=450.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 15, 'p': 6}, min_start_time=450.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 0}, min_start_time=480.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 1}, min_start_time=480.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 2}, min_start_time=480.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 3}, min_start_time=480.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 4}, min_start_time=480.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 5}, min_start_time=480.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 16, 'p': 6}, min_start_time=480.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 0}, min_start_time=510.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 1}, min_start_time=510.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 2}, min_start_time=510.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 3}, min_start_time=510.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 4}, min_start_time=510.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 5}, min_start_time=510.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 17, 'p': 6}, min_start_time=510.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 0}, min_start_time=540.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 1}, min_start_time=540.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 2}, min_start_time=540.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 3}, min_start_time=540.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 4}, min_start_time=540.0, x_pos=-9154.8, y_pos=-9270.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 5}, min_start_time=540.0, x_pos=-8061.6, y_pos=-8840.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 18, 'p': 6}, min_start_time=540.0, x_pos=-7662.4, y_pos=-8371.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 19, 'p': 0}, min_start_time=570.0, x_pos=-10732.0, y_pos=-7458.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 19, 'p': 1}, min_start_time=570.0, x_pos=-10464.7, y_pos=-8424.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 19, 'p': 2}, min_start_time=570.0, x_pos=-10331.6, y_pos=-9088.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
#  RTMEvent(index={'t': 19, 'p': 3}, min_start_time=570.0, x_pos=-9819.2, y_pos=-9307.0, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None)), stim_channels=(PowerChannel(config='CyanStim', exposure=250, group='TTL_ERK', power=18),)),
# ...
#  RTMEvent(index={'t': 61, 'p': 7}, min_start_time=4078.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 8}, min_start_time=4078.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 9}, min_start_time=4078.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 10}, min_start_time=4078.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 11}, min_start_time=4078.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 12}, min_start_time=4078.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 61, 'p': 13}, min_start_time=4078.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 7}, min_start_time=4108.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 8}, min_start_time=4108.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 9}, min_start_time=4108.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 10}, min_start_time=4108.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 11}, min_start_time=4108.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 12}, min_start_time=4108.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 62, 'p': 13}, min_start_time=4108.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 7}, min_start_time=4138.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 8}, min_start_time=4138.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 9}, min_start_time=4138.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 10}, min_start_time=4138.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 11}, min_start_time=4138.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 12}, min_start_time=4138.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 63, 'p': 13}, min_start_time=4138.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 7}, min_start_time=4168.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 8}, min_start_time=4168.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 9}, min_start_time=4168.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 10}, min_start_time=4168.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 11}, min_start_time=4168.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 12}, min_start_time=4168.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 64, 'p': 13}, min_start_time=4168.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 7}, min_start_time=4198.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 8}, min_start_time=4198.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 9}, min_start_time=4198.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 10}, min_start_time=4198.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 11}, min_start_time=4198.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 12}, min_start_time=4198.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 65, 'p': 13}, min_start_time=4198.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 7}, min_start_time=4228.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 8}, min_start_time=4228.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 9}, min_start_time=4228.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 10}, min_start_time=4228.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 11}, min_start_time=4228.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 12}, min_start_time=4228.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 66, 'p': 13}, min_start_time=4228.0, x_pos=-4363.7, y_pos=-7027.8, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 7}, min_start_time=4258.0, x_pos=-7452.5, y_pos=-7950.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 8}, min_start_time=4258.0, x_pos=-7833.6, y_pos=-7426.3, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 9}, min_start_time=4258.0, x_pos=-6956.0, y_pos=-6397.5, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 10}, min_start_time=4258.0, x_pos=-5753.4, y_pos=-6439.4, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 11}, min_start_time=4258.0, x_pos=-5183.8, y_pos=-6120.1, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  RTMEvent(index={'t': 67, 'p': 12}, min_start_time=4258.0, x_pos=-4600.4, y_pos=-6473.9, metadata={'phase_name': 'RandomPatchStim', 'phase_id': 0, 'treatment_name': 'Random per-cell 14px-patch stimulation'}, channels=(Channel(config='mScarlet3', exposure=200.0, group=None), Channel(config='miRFP', exposure=1100.0, group=None))),
#  ...]

# %% [markdown]
# ### Validate Experiment
#
# `validate_events` checks FOV positions, channel configs, and pipeline compatibility (in particular,
# that the new stim class accepts the right call signature and that no required metadata is missing).

# %%
ctrl = Controller(mic, pipeline, writer=writer)
ctrl.validate_events(events)

# Async status widget: docks into napari and re-binds automatically on
# every ctrl.run_experiment call. Shows the event strip, FOV map, lag,
# and a Stop button to cancel the run.
from faro.widgets import ExperimentStatusWidget

status_wdg = ExperimentStatusWidget(ctrl)
viewer.window.add_dock_widget(status_wdg, name="Experiment status")

# %% [markdown]
# ### Run experiment
#
# Optional sleep loop delays acquisition start (`SLEEP_BEFORE_EXPERIMENT_START_in_H`).
# Disconnect the napari live view before the MDA engine takes over the camera.

# %%
for _ in range(0, int(SLEEP_BEFORE_EXPERIMENT_START_in_H * 3600)):
    time.sleep(1)

# run_experiment is async: it returns a RunHandle immediately and drives
# the MDA on a worker thread, so this cell does NOT block. Watch the
# "Experiment status" widget for live progress; use its Stop button (or
# handle.cancel()) to abort. The controller stops napari-mm live mode
# itself, so the old mm_wdg._core_link.cleanup() workaround is gone.
handle = ctrl.run_experiment(events, stim_mode="current")

# handle.status()  -> RunStatus snapshot
# handle.cancel()  -> request graceful stop
# handle.wait()    -> block here until the run finishes (optional;
#                     finish_experiment() in the next section also waits)

# %% [markdown]
# ### Post-processing
#
# The run is **asynchronous** — `ctrl.run_experiment` above returned immediately.
# `finish_experiment()` below **blocks until the run actually finishes** before
# tearing down, so it doubles as the "wait for completion" step. (To wait
# explicitly without tearing down, call `handle.wait()`.)
#
# 1. `finish_experiment()` waits for the run, flushes the pipeline queue, and closes the zarr writer.
# 2. `generate_exp_data_from_tracks()` merges per-FOV tracks into a single `exp_data.parquet`.
# 3. The patch coordinates accumulated by the stimulator are merged directly into `exp_data.parquet` on `(fov, fov_timestep, label)`. Stim-frame rows for stimulated cells gain `patch_y_min`, `patch_x_min`, `patch_y_max`, `patch_x_max`, `patch_dot_y`, `patch_dot_x`, etc.; all other rows get NaN for these columns.
# 4. Reconnect the napari live view.

# %%
ctrl.finish_experiment()

# %%
import pandas as pd

ctrl.finish_experiment()
utils.generate_exp_data_from_tracks(path)

# Merge the patch coordinates accumulated by the stimulator into exp_data.parquet,
# joining on (fov, fov_timestep, label). Drop any duplicate stim calls per cell.
exp_data_path = os.path.join(path, "exp_data.parquet")
df_exp = pd.read_parquet(exp_data_path)
df_patches = stimulator.to_dataframe().drop_duplicates(
    subset=["fov", "fov_timestep", "label"]
)
if not df_patches.empty:
    df_exp = df_exp.merge(
        df_patches, on=["fov", "fov_timestep", "label"], how="left"
    )
df_exp.to_parquet(exp_data_path)
print(f"Merged {len(df_patches)} patch rows into {exp_data_path}")

from napari_micromanager._core_link import CoreViewerLink

if "viewer" in locals():
    mm_wdg._core_link = CoreViewerLink(viewer, mic.mmc)
# Out:
# Merged 0 patch rows into Z:\lhinder\data\rtm_mm_data\exp_434\random_stim_per_cell_14px_patches\exp_data.parquet

# %%
df_exp
# Out:
#        label           x           y       phase_name  phase_id  \
# 0          1  168.564502  512.610127  RandomPatchStim         0
# 1          2  268.869988  574.005772  RandomPatchStim         0
# 2          3  325.424347  223.136176  RandomPatchStim         0
# 3          4  621.185318  536.103871  RandomPatchStim         0
# 4          5  651.802817  155.470825  RandomPatchStim         0
# ...      ...         ...         ...              ...       ...
# 12010      2  290.683703  749.783028  RandomPatchStim         0
# 12011      3  561.919690  215.785417  RandomPatchStim         0
# 12012      1  171.062636  848.642081  RandomPatchStim         0
# 12013      2  290.400473  749.852482  RandomPatchStim         0
# 12014      3  561.020705  216.412353  RandomPatchStim         0
#
#                                treatment_name  fov  timestep      fname  \
# 0      Random per-cell 14px-patch stimulation    0         0  000_00000
# 1      Random per-cell 14px-patch stimulation    0         0  000_00000
# 2      Random per-cell 14px-patch stimulation    0         0  000_00000
# 3      Random per-cell 14px-patch stimulation    0         0  000_00000
# 4      Random per-cell 14px-patch stimulation    0         0  000_00000
# ...                                       ...  ...       ...        ...
# 12010  Random per-cell 14px-patch stimulation    9        63  009_00063
# 12011  Random per-cell 14px-patch stimulation    9        63  009_00063
# 12012  Random per-cell 14px-patch stimulation    9        64  009_00064
# 12013  Random per-cell 14px-patch stimulation    9        64  009_00064
# 12014  Random per-cell 14px-patch stimulation    9        64  009_00064
#
#          time  ...  stim_exposure ref_mean_intensity patch_i patch_j  \
# 0         0.0  ...            NaN                NaN     NaN     NaN
# 1         0.0  ...            NaN                NaN     NaN     NaN
# 2         0.0  ...            NaN                NaN     NaN     NaN
# 3         0.0  ...            NaN                NaN     NaN     NaN
# 4         0.0  ...            NaN                NaN     NaN     NaN
# ...       ...  ...            ...                ...     ...     ...
# 12010  3222.0  ...            NaN                NaN     NaN     NaN
# 12011  3222.0  ...            NaN                NaN     NaN     NaN
# 12012  3232.0  ...            NaN                NaN     NaN     NaN
# 12013  3232.0  ...            NaN         525.229787     NaN     NaN
# 12014  3232.0  ...            NaN         451.229085     NaN     NaN
#
#        patch_y_min patch_x_min  patch_y_max  patch_x_max  patch_dot_y  \
# 0              NaN         NaN          NaN          NaN          NaN
# 1              NaN         NaN          NaN          NaN          NaN
# 2              NaN         NaN          NaN          NaN          NaN
# 3              NaN         NaN          NaN          NaN          NaN
# 4              NaN         NaN          NaN          NaN          NaN
# ...            ...         ...          ...          ...          ...
# 12010          NaN         NaN          NaN          NaN          NaN
# 12011          NaN         NaN          NaN          NaN          NaN
# 12012          NaN         NaN          NaN          NaN          NaN
# 12013          NaN         NaN          NaN          NaN          NaN
# 12014          NaN         NaN          NaN          NaN          NaN
#
#        patch_dot_x
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 12010          NaN
# 12011          NaN
# 12012          NaN
# 12013          NaN
# 12014          NaN
#
# [12015 rows x 40 columns]
